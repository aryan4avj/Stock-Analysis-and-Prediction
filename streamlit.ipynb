# %% [markdown]
# <a href="https://colab.research.google.com/github/AryanWadhwa05/Stock-Analysis-and-Prediction/blob/main/streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile app.py
import streamlit as st
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data as pdr


# download dataframe
st.title("Stock Market Analysis")

#sidebar

# st.file_uploader("Upload CSV")

st.sidebar.title("Stocks")

st.sidebar.subheader("Stock Search")

# st.sidebar.selectbox("Example",["Facebook","Apple","Alphabet"])
stock_search = st.sidebar.multiselect('Stock Search', ["FB","AAPL","Alphabet"],default = "FB")
display_cols = st.sidebar.multiselect('Display Data', ["Close","Adj Close","Low","Open","High","Volume"],default = "High")
graph_type = st.sidebar.selectbox('Graph Type', ["Line","Bar","Vega Lite","AltAir","High","Volume"])

start_date = st.sidebar.date_input('Start Date')
end_date = st.sidebar.date_input('End Date')

# st.write(start_date)

yf.pdr_override()
tickers = ""
for i in stock_search:
  tickers += i + " "

st.write(tickers)
# sample_data=pdr.get_data_yahoo(stock_search[i], start=start_date, end=end_date)
data = yf.download(tickers, start=start_date, end=end_date)
st.write(data)

dataframe = data[display_cols]
st.write(dataframe)
st.line_chart(dataframe)

# plt.plot(dataframe)
    
# st.pyplot(plt)

# data1 = pdr.get_data_yahoo("FB", start=start_date, end=end_date)

# dataframe = pd.DataFrame()

# for i in stock_search:
#   dataframe[i]
#   data=yf.download(i, start=start_date, end=end_date)
#   dataframe[i] = data["High"]

# st.write(dataframe)
# dataframe1

# dataframe1 = data1["Low"]
# dataframe1 = dataframe1["Apple"]
# dataframe1["Apple"] = data["Low"]

# data_frame = data[display_cols]
# data = data.drop(["Volume","Close","Adj Close","Low","Open"],axis = 1)

# st.pyplot(data)

# st.line_chart(dataframe)
# Out:
# Writing app.py

# %%
#@title Run this cell to load some data
# !pip -q install streamlit > /dev/null
# !pip -q install pyngrok > /dev/null
# !pip install yfinance

import tensorflow as tf
import pandas as pd
import cv2
import plotly.express as px
import numpy as np
import yfinance as yf
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.20 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.3.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.27.0 which is incompatible.
# ...
#      |████████████████████████████████| 6.3 MB 5.9 MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23918 sha256=7b8931798fa36e6cecfd49853362b9e8f2651b2da57c9040d7d565b5556fbe49
#   Stored in directory: /root/.cache/pip/wheels/fe/87/8b/7ec24486e001d3926537f5f7801f57a74d181be25b11157983
# Successfully built yfinance
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
# ...

# %%
from pyngrok import ngrok
#Publish Web App (Run this again whenever you make changes)
public_url = ngrok.connect(port='80')
print (public_url)
# !streamlit run --server.port 80 app.py
# Out:
# NgrokTunnel: "http://b578-35-196-106-72.ngrok.io" -> "http://localhost:80"
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:80
#   External URL: http://35.196.106.72:80
#
# 2021-09-09 02:12:46.656 NumExpr defaulting to 2 threads.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  3 of 3 completed
#
# 1 Failed download:
# - P: No data found for this date range, symbol may be delisted
# 2021-09-09 02:14:05.096 Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/streamlit/script_runner.py", line 354, in _run_script
#     exec(code, module.__dict__)
#   File "/content/app.py", line 42, in <module>
#     st.line_chart(dataframe)
# ...

# %%
# %%writefile app.py

import streamlit as st
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data as pdr
import plotly.express as px

# download dataframe
st.title("Stock Market Analysis")

#sidebar

# st.file_uploader("Upload CSV")

st.sidebar.title("Stocks")

st.sidebar.subheader("Stock Search")

# st.sidebar.selectbox("Example",["Facebook","Apple","Alphabet"])
# stock_search = st.sidebar.multiselect('Stock Search', ["FB","AAPL","Alphabet"],default = "FB")
stock_search_test = st.sidebar.text_input('Stock Search')
display_cols = st.sidebar.multiselect('Display Data', ["Close","Adj Close","Low","Open","High","Volume"],default = "High")
graph_type = st.sidebar.selectbox('Graph Type', ["Line","Bar","Vega Lite","AltAir","High","Volume"])

start_date = st.sidebar.date_input('Start Date')
end_date = st.sidebar.date_input('End Date')

# st.write(start_date)

yf.pdr_override()
tickers = ""

tickers = stock_search_test.replace(","," ")

# for i in stock_search_test:
  # tickers += i + " "

# st.write(tickers)
# sample_data=pdr.get_data_yahoo(stock_search[i], start=start_date, end=end_date)
data = yf.download(tickers, start=start_date, end=end_date)
# st.write(data)

dataframe = data[display_cols]
st.write(dataframe)
# st.line_chart(dataframe)

# fig = px.line(dataframe,y="High")
# fig.show()
# st.plotly_chart(fig)

plt.plot(dataframe)
plt.legend(dataframe)

st.pyplot(plt)

# data1 = pdr.get_data_yahoo("FB", start=start_date, end=end_date)

# dataframe = pd.DataFrame()

# for i in stock_search:
#   dataframe[i]
#   data=yf.download(i, start=start_date, end=end_date)
#   dataframe[i] = data["High"]

# st.write(dataframe)
# dataframe1

# dataframe1 = data1["Low"]
# dataframe1 = dataframe1["Apple"]
# dataframe1["Apple"] = data["Low"]

# data_frame = data[display_cols]
# data = data.drop(["Volume","Close","Adj Close","Low","Open"],axis = 1)

# st.pyplot(data)

# st.line_chart(dataframe)
